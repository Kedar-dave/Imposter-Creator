# %%
# Import Module
from tkinter import *

# create root window
root = Tk()

# root window title and dimension
root.title("Welcome to GeekForGeeks")
root.resizable(False, False)
root.geometry('500x500')
# bgimg= PhotoImage(file = "bg.jpg")

canvas1 = Canvas( root, width = 400, height = 400)
  
# canvas1.pack(fill = "both", expand = True)
  
# Display image
# canvas1.create_image( 0, 0, image= bgimg, anchor = "nw")

# adding a label to the root window
lbl = Label(root, text = "Are you a Geek?")
lbl.grid()

# adding Entry Field
txt = Entry(root, width=10)
txt.grid(column =1, row =0)


# function to display user text when
# button is clicked
def clicked():

	res = "You wrote: " + txt.get()
	lbl.configure(text = res)

# button widget with red color text inside
btn = Button(root, text = "Click me" ,
			fg = "red", command=clicked)
# Set Button Grid
btn.grid(column=2, row=0)

# Execute Tkinter
root.mainloop()

# %%
import tkinter as tk
from tkinter import ttk
from tkinter import filedialog as fd
from tkinter.messagebox import showinfo

# create the root window
root = tk.Tk()
root.title('Tkinter Open File Dialog')
root.resizable(False, False)
root.geometry('300x150')


def select_file():
    filetypes = (
        ('Mp4 files', '*.mp4'),
        ('Mkv files', '*.mkv'),
        ('MOV files', '*.mov'),
        ('All files', '*.*')
    )

    filename = fd.askopenfilename(
        title='Open a file',
        initialdir='/',
        filetypes=filetypes)

    showinfo(
        title='Selected File',
        message=filename
    )


# open button
open_button = ttk.Button(
    root,
    text='Open a File',
    command=select_file
)

open_button.pack(expand=True)


# run the application
root.mainloop()

# %%
from operator import ge
from tkinter import *
from turtle import window_height, window_width
from PIL import ImageTk, Image  
root = Tk()
root.title('DeepFake Program!!')

screen_width = root.winfo_screenwidth()
screen_height = root.winfo_screenheight()

def getwidth():
    width = root.winfo_width()
    return width
def getheight():
    height = root.winfo_height()
    return height
root.geometry(str(screen_width)+'x'+str(screen_height))
#Head and Background
background_canvas = Canvas(root,bg='white', height=getheight(), width=getwidth())

placeholder_img = Image.open("F:/Wallpapers/sunset ambience.jpg")

img = placeholder_img.resize((getwidth(), getheight()))
bg_img = ImageTk.PhotoImage(img)
print(getheight(),getwidth())
background_canvas.create_image(0,0,anchor=NW,image=bg_img)
background_canvas.pack()
def clicked():
    print(getheight(),getwidth())
btn_canvas = Canvas(root, width=330, height=200, bg="red")
btn_canvas.place(x=50, y=50)

btn = Button(root, text='Welcome to Tkinter!', width=40,
             height=5, bd='10', command=clicked)
  
btn.place(x=65, y=100)


root.mainloop()
# Out:
# 1 1
# 845 1536

# %%
from tkinter import *
from PIL import ImageTk, Image  
root = Tk()
root.title("Deepfake Program!!")
root.geometry(str(root.winfo_screenwidth())+'x'+str(root.winfo_screenheight()))

bg_canvas = Canvas(root, bg='black', width= root.winfo_width(), height= root.winfo_height())

p_img = (Image.open("F:/Wallpapers/sunset ambience.jpg"))
img = p_img.resize((root.winfo_width(), root.winfo_height()))
bg_img = ImageTk.PhotoImage(img)
label1 = Label(image=bg_img)
label1.image = bg_img
label1.pack()
# bg_canvas.create_image(0,0,anchor=NW,image=bg_img)
# bg_canvas.pack()
root.mainloop()
